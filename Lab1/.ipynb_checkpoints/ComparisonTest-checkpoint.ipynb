# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
comparison_5 = pd.read_csv("results_comparison5.csv")[490:501]
comparison_6 = pd.read_csv("results_comparison6.csv")[490:501]
comparison_7 = pd.read_csv("results_comparison7.csv")[490:501]
comparison_8 = pd.read_csv("results_comparison8.csv")[490:501]
comparison_9 = pd.read_csv("results_comparison9.csv")[490:501]
comparison_10 = pd.read_csv("results_comparison10.csv")[490:501]
comparison_11 = pd.read_csv("results_comparison11.csv")[490:501]
comparison_12 = pd.read_csv("results_comparison12.csv")[490:501]
comparison_13 = pd.read_csv("results_comparison13.csv")[490:501]
comparison_14 = pd.read_csv("results_comparison14.csv")[490:501]
comparison_15 = pd.read_csv("results_comparison15.csv")[490:501]
comparison_16 = pd.read_csv("results_comparison16.csv")[490:501]

# %%
plt.figure(figsize=(36,24))
ax = sb.lineplot(x= comparison_5["Array Size"], y= comparison_5["difference"], label='hybridSort_5')
ax = sb.lineplot(x= comparison_6["Array Size"], y= comparison_6["difference"],label='hybridSort_6')
ax = sb.lineplot(x= comparison_7["Array Size"], y= comparison_7["difference"], label='hybridSort_7')
ax = sb.lineplot(x= comparison_8["Array Size"], y= comparison_8["difference"], label='hybridSort_8')
ax = sb.lineplot(x= comparison_9["Array Size"], y= comparison_9["difference"],label='hybridSort_9')
ax = sb.lineplot(x= comparison_10["Array Size"], y= comparison_10["difference"],label='hybridSort_10')
ax = sb.lineplot(x= comparison_11["Array Size"], y= comparison_11["difference"],label='hybridSort_11')
ax = sb.lineplot(x= comparison_12["Array Size"], y= comparison_12["difference"],label='hybridSort_12')
ax = sb.lineplot(x= comparison_13["Array Size"], y= comparison_13["difference"],label='hybridSort_13')
ax = sb.lineplot(x= comparison_14["Array Size"], y= comparison_14["difference"],label='hybridSort_14')
ax = sb.lineplot(x= comparison_15["Array Size"], y= comparison_15["difference"],label='hybridSort_15')
ax.set(ylabel="Comparison")
# Out:
# [Text(0, 0.5, 'Comparison')]

# %%
print(comparison_5['difference'].mean())
# Out:
# 254.6

# %%
print(comparison_6['difference'].mean())
# Out:
# 252.3

# %%
print(comparison_7['difference'].mean())
# Out:
# 249.9

# %%
print(comparison_8['difference'].mean())
# Out:
# 255.7

# %%
print(comparison_9['difference'].mean())
# Out:
# 272.6

# %%
print(comparison_10['difference'].mean())
# Out:
# 269.1

# %%
print(comparison_11['difference'].mean())
# Out:
# 278.0

# %%
print(comparison_12['difference'].mean())
# Out:
# 278.0

# %%
print(comparison_13['difference'].mean())
# Out:
# 288.1

# %%
print(comparison_14['difference'].mean())
# Out:
# 251.1

# %%
print(comparison_15['difference'].mean())
# Out:
# 270.4

# %%
print(comparison_16['difference'].mean())
# Out:
# 96.3
