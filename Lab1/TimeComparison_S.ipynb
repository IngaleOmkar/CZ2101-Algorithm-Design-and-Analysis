# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %%
data = pd.read_csv('Time_S.csv')

# %%
data
# Out:
#       s  HybridSort  MergeSort
# 0     4   17.054083  15.038291
# 1     5   13.639000  13.303417
# 2     6   13.044375  13.381500
# 3     7   13.215875  13.358208
# 4     8   12.901250  13.278000
# ..  ...         ...        ...
# 92   96   13.909875  13.870208
# 93   97   14.051833  13.456833
# 94   98   13.347584  13.020167
# 95   99   13.029459  12.965542
# 96  100   13.062250  12.741708
#
# [97 rows x 3 columns]

# %%
plt.figure(figsize=(24,12))
ax = sb.lineplot(x=data["s"], y=data["MergeSort"], color='blue', label='mergeSort')
ax = sb.lineplot(x=data["s"], y=data["HybridSort"], color='red', label='hybridSort')
ax.set(ylabel="Time (ms)")
# Out:
# [Text(0, 0.5, 'Time (ms)')]

# %%
plt.figure(figsize=(24,12))
ax = sb.lineplot(x=data["s"], y=data["MergeSort"]-data["HybridSort"], color='blue', label='Merge - Hybrid')
ax.set(ylabel="Difference in Time (ms)")
# Out:
# [Text(0, 0.5, 'Difference in Time (ms)')]
