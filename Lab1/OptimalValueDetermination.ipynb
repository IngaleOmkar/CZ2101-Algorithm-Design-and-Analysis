# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv("optimal.csv")

# %%
data
# Out:
#      S  SavedComparisons
# 0    4               161
# 1    5               214
# 2    6               235
# 3    7               257
# 4    8               267
# 5    9               269
# 6   10               264
# 7   11               256
# 8   12               239
# 9   13               213
# 10  14               179
# 11  15               137
# 12  16                81
# 13  17                52
# 14  18                34
# 15  19                 7
# 16  20               -19
# 17  21               -55
# 18  22               -91
# 19  23              -140
# 20  24              -188
# 21  25              -244
# 22  26              -306
# 23  27              -377
# 24  28              -458
# 25  29              -540
# 26  30              -633
# 27  31              -734
# 28  32              -818
# 29  33              -849
# 30  34              -886
# 31  35              -913
# 32  36              -952
# 33  37              -988
# 34  38             -1035
# 35  39             -1075
# ...

# %%
plt.figure(figsize = (24,12))
ax = sb.lineplot(x=data["S"], y=data["SavedComparisons"], color='blue', label='Mean Comparison difference')
